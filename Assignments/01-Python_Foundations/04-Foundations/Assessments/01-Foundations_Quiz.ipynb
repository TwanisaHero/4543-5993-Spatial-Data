# %% [markdown]
# # 📝 Foundations Quiz
#
# This quiz covers material from the **Foundations** notebooks (01–08).
# Answer each question in the provided cell. Some questions require code, others are written answers.

# %% [markdown]
# ## Q1. Magics
# What does `%whos` display? Write your answer below.

# %% [markdown]
# `%whos` displays the variables currently defined in the notebook session, including their type, value/data preview, and other summary information.

# %% [markdown]
# ## Q2. Markdown
# Create a Markdown cell with a heading `## My Hobbies` and a bullet list of at least 3 hobbies.

# %% [markdown]
# ## My Hobbies
#
# - Reading
# - Coding small projects
# - Playing games

# %% [markdown]
# ## Q3. Files and Paths
# Use `%pwd` to print your current working directory.

# %%
# %pwd
# Out:
# 'C:\\Users\\demii\\OneDrive\\Desktop\\4543-5993-Spatial-Data\\Assignments\\01-Python_Foundations\\04-Foundations\\Assessments'

# %% [markdown]
# ## Q4. File I/O
# Write Python code that saves `Hello World` to a file called `hello.txt`, then reads it back and prints the contents.

# %%
with open("hello.txt", "w", encoding="utf-8") as file:
    file.write("Hello World")

with open("hello.txt", "r", encoding="utf-8") as file:
    contents = file.read()

print(contents)
# Out:
# Hello World

# %% [markdown]
# ## Q5. Data I/O
# Load the file `students.csv` (or create a small CSV yourself) with Pandas and show the first 5 rows.

# %%
import pandas as pd

students = pd.DataFrame({
    "name": ["Ava", "Ben", "Cora", "Diego", "Ella"],
    "major": ["CS", "Math", "Data", "GIS", "CS"],
    "score": [92, 85, 88, 95, 90],
})
students.to_csv("students.csv", index=False)

df = pd.read_csv("students.csv")
df.head()
# Out:
#     name major  score
# 0    Ava    CS     92
# 1    Ben  Math     85
# 2   Cora  Data     88
# 3  Diego   GIS     95
# 4   Ella    CS     90

# %% [markdown]
# ## Q6. Plotting
# Create a line plot of $y = x^2$ for $x$ values from 0 to 10.

# %%
import matplotlib.pyplot as plt

x = list(range(11))
y = [value ** 2 for value in x]

plt.plot(x, y, marker="o")
plt.xlabel("x")
plt.ylabel("x squared")
plt.title("Line Plot of y = x^2")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Q7. Shortcuts
# In Command mode, what keyboard shortcut deletes a cell?

# %% [markdown]
# In Jupyter command mode, pressing `D` twice deletes the selected cell.

# %% [markdown]
# ## Q8. Help and Docs
# Use `?` to display the docstring for `len`. Show the result.

# %%
# %pinfo len

# %% [markdown]
# ## Q9. Timing
# Compare the runtime of squaring numbers using a Python loop vs. NumPy. Use `%timeit` for each.

# %%
import numpy as np

numbers = list(range(10000))
array = np.arange(10000)

# %timeit [x ** 2 for x in numbers]
# %timeit array ** 2
# Out:
# 399 μs ± 14.1 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 3.86 μs ± 155 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Q10. Reflection
# Why is it useful to mix Markdown and code in Jupyter notebooks? Write 2–3 sentences.

# %% [markdown]
# Markdown explains what the code is doing, while code shows the actual computation. Mixing them makes a notebook easier to read, easier to reproduce, and more useful as a record of both the process and the result.
