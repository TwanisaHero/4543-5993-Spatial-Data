# %% [markdown]
# # ⏱️ 08 - Timing and Performance
#
# In data science, performance matters. Some code runs fast, some slow.
# Jupyter/IPython gives us tools to measure runtime easily.
#
# In this notebook you will learn:
# - `%time` and `%timeit` for single expressions
# - `%%time` and `%%timeit` for entire cells
# - Comparing loops, list comprehensions, and NumPy
# - Why performance awareness is important

# %% [markdown]
# ## 1. `%time`

# %%
# %time sum(range(1_000_000))
# Out:
# CPU times: total: 15.6 ms
# Wall time: 11.6 ms
# 499999500000

# %% [markdown]
# ✅ **Your Turn**: Use `%time` to measure how long it takes to sort a list of 1 million random numbers.

# %%
# Completed reference solution
import random
numbers = [random.random() for _ in range(1_000_000)]
# %time sorted_numbers = sorted(numbers)
# Out:
# CPU times: total: 188 ms
# Wall time: 200 ms

# %% [markdown]
# ## 2. `%timeit`

# %%
numbers = list(range(1_000))
# %timeit [x**2 for x in numbers]
# Out:
# 41.1 μs ± 610 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ✅ **Your Turn**: Compare `%timeit` results for a list comprehension vs. a `for` loop that builds the same list.

# %%
# Completed reference solution: loop vs comprehension
# %timeit [x ** 2 for x in range(10000)]

def build_with_loop():
    result = []
    for x in range(10000):
        result.append(x ** 2)
    return result
# %timeit build_with_loop()
# Out:
# 470 μs ± 13 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 508 μs ± 2.18 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## 3. `%%time` for a Whole Cell

# %%
# %%timeit
total = 0
for i in range(1_000_000):
    total += i
total
# Out:
# 31 ms ± 1.27 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ✅ **Your Turn**: Wrap a longer multi-line operation with `%%time` to measure its runtime.

# %%
# %%time
# Completed reference solution: multiline timing
total = 0
for number in range(1_000_000):
    total += number ** 2
print(total)
# Out:
# 333332833333500000
# CPU times: total: 93.8 ms
# Wall time: 122 ms

# %% [markdown]
# ## 4. Comparing Loops vs. NumPy

# %%
import numpy as np

numbers = np.arange(1_000_000)

# Python loop
# %timeit [x**2 for x in numbers]

# NumPy vectorized
# %timeit numbers**2
# Out:
# 87.6 ms ± 1.81 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.69 ms ± 37 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ✅ **Your Turn**: Try squaring numbers with a Python loop, list comprehension, and NumPy array. Compare times.

# %%
# Completed reference solution: three square timings
import numpy as np
def square_loop(values):
    result = []
    for value in values:
        result.append(value ** 2)
    return result
values = list(range(10000))
array = np.arange(10000)
# %timeit square_loop(values)
# %timeit [value ** 2 for value in values]
# %timeit array ** 2
# Out:
# 465 μs ± 12 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 390 μs ± 8.58 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 3.76 μs ± 55.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## 5. Why This Matters
# - Performance differences become huge with large datasets.
# - Vectorized operations (like NumPy, Pandas) are usually faster.
# - `%timeit` is your friend when deciding how to implement something.

# %% [markdown]
# ---
# ### Summary
# - `%time` and `%timeit` measure execution speed.
# - `%%time` and `%%timeit` work on whole cells.
# - Loops are slower than list comprehensions, which are slower than NumPy.
# - Always measure performance before optimizing.
