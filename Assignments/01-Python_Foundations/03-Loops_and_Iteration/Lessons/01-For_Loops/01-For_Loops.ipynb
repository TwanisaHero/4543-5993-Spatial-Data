# %% [markdown]
# # 📘 01 - For Loops
#
# Learn how to use `for` loops to iterate over sequences.

# %% [markdown]
# ## ✅ Learning Goals
# - Use `for` with lists, strings, and `range()`
# - Understand loop variables and block structure

# %%
# 🔁 Loop over a list
fruits = ['apple', 'banana', 'cherry']
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %%
# 🔁 Loop over characters in a string
word = 'hello'
for char in word:
    print(char)
# Out:
# h
# e
# l
# l
# o

# %%
# 🔁 Using range()
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# ➕ Loop with math
for i in range(1, 6):
    print(f'{i} squared is', i ** 2)
# Out:
# 1 squared is 1
# 2 squared is 4
# 3 squared is 9
# 4 squared is 16
# 5 squared is 25

# %% [markdown]
# ### ✏️ Your Turn
# Loop over a list of 3 favorite movies and print them in all caps.

# %%
# Completed reference solution
movies = ["arrival", "inception", "hidden figures"]
for movie in movies:
    print(movie.upper())
# Out:
# ARRIVAL
# INCEPTION
# HIDDEN FIGURES
