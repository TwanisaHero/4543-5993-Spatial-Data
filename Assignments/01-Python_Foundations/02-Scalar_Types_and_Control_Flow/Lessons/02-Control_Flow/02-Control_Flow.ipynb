# %% [markdown]
# # 📘 02 - Control Flow
#
# Learn how to use conditional logic in Python.

# %% [markdown]
# ## ✅ Learning Goals
# - Write `if`, `elif`, `else` statements
# - Understand truthy/falsy values
# - Combine conditions using `and`, `or`, `not`

# %%
# 🔧 Basic example
age = 20
if age >= 18:
    print('You are an adult.')
else:
    print('You are a minor.')
# Out:
# You are an adult.

# %% [markdown]
# ## 🔀 Multiple Branches

# %%
temp = 72
if temp > 90:
    print('Too hot!')
elif temp < 60:
    print('Too cold!')
else:
    print('Just right.')
# Out:
# Just right.

# %% [markdown]
# ### ✏️ Your Turn
# Use `input()` to ask a user their grade and print a message based on value.

# %%
# Completed reference solution
# Fixed score keeps the notebook runnable; replace with input() for interaction.
grade = 88

if grade >= 90:
    print("A: excellent work")
elif grade >= 80:
    print("B: solid work")
elif grade >= 70:
    print("C: passing, but keep practicing")
else:
    print("Needs more practice")
# Out:
# B: solid work

# %%
# Example:
# grade = int(input('Enter your score: '))
# if grade >= 90:
#     print('A')
# elif grade >= 80:
#     print('B')
# ...
