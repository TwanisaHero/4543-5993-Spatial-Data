# %% [markdown]
# ## ❓ Mini Quiz: 02 - Scalar Types and Control Flow
#
# Answer the questions below. You may write answers in Markdown cells or experiment in code cells where provided.

# %% [markdown]
# ### 1️⃣ Which type is returned by this expression?
# ```python
# type(True)
# ```

# %%
# Answer 1
# type(True) returns bool.
type(True)
# Out:
# bool

# %% [markdown]
# ### 2️⃣ Given the following snippet:
#
# ```python
# x = 7
# y = 15
# z = 11
# ```
# Write a boolean statement that would print true if the value in z was between x and y.

# %%
# Answer 2
x = 7
y = 15
z = 11
print(x < z < y)
# Out:
# True

# %% [markdown]
# ### 3️⃣ Add one keyword to your boolean statement from above that would print false instead of true.

# %%
# Answer 3
x = 7
y = 15
z = 11
print(not (x < z < y))
# Out:
# False

# %% [markdown]
# Adding the keyword `not` negates the boolean expression, so a true expression becomes false.

# %% [markdown]
# ## 4️⃣ Fill in the blank to check for inequality:
# ```python
# if score != 100:
#     print("Not a perfect score")
# ```

# %%
# Answer 4
score = 95
if score != 100:
    print("Not a perfect score")
# Out:
# Perfect score!

# %% [markdown]
# ## 5️⃣ Given the following:
#
# ```Python
# a = 11
#
# if a % 2 == 0:
#     print("Variable is even")
# ```
#
# Add to the if statement so that it will also print "Variable is odd" depending on the number.

# %%
# Answer 5
a = 11

if a % 2 == 0:
    print("Variable is even")
else:
    print("Variable is odd")
# Out:
# Variable is odd

# %% [markdown]
# The `else` block runs when the `if` condition is false, so odd numbers are handled there.
