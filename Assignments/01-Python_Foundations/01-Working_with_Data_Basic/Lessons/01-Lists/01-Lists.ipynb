# %% [markdown]
# # 📘 01 - Python Lists
#
# Explore how to use lists to store and manipulate data.

# %% [markdown]
# ## ✅ Learning Goals
# - Create and modify Python lists
# - Access elements using indexing
# - Use list methods like `append()`, `remove()`, and `sort()`

# %%
# 🔧 Create a List
my_list = [10, 20, 30, 40, 50]
print(my_list)
# Out:
# [10, 20, 30, 40, 50]

# %%
# 🎯 Access Elements
print('First item:', my_list[0])
print('Last item:', my_list[-1])
# Out:
# First item: 10
# Last item: 50

# %%
# ➕ Modify List
my_list.append(60)
my_list.remove(30)
print(my_list)
# Out:
# [10, 20, 40, 50, 60]

# %%
# 🔁 Loop Through List
for item in my_list:
    print(item)
# Out:
# 10
# 20
# 40
# 50
# 60

# %% [markdown]
# ## ✏️ Your Turn
# Create your own list of 5 favorite movies and sort them alphabetically.

# %%
# Completed reference solution
favorite_movies = ["Arrival", "Inception", "The Matrix", "Hidden Figures", "Spirited Away"]
favorite_movies.sort()
print(favorite_movies)
# Out:
# ['Arrival', 'Hidden Figures', 'Inception', 'Spirited Away', 'The Matrix']
