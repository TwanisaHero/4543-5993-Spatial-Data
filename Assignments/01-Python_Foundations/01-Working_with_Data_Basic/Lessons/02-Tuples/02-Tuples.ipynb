# %% [markdown]
# # 📘 02 - Python Tuples
#
# Learn what tuples are and how to use them.

# %% [markdown]
# ## ✅ Learning Goals
# - Create and access tuples
# - Understand immutability
# - Use tuple unpacking

# %%
# 🔧 Create a Tuple
coords = (5, 10)
print(coords)
# Out:
# (5, 10)

# %%
# 🔍 Indexing
print('X:', coords[0])
print('Y:', coords[1])
# Out:
# X: 5
# Y: 10

# %%
# 🔁 Tuple Unpacking
x, y = coords
print('x + y =', x + y)
# Out:
# x + y = 15

# %% [markdown]
# ## 🚫 Tuples are immutable
# Try uncommenting the line below to see what happens:
# ```python
# # coords[0] = 100
# ```

# %% [markdown]
# ## ✏️ Your Turn
# Create a tuple to store your birthday as `(month, day, year)`.

# %%
# Completed reference solution
birthday = (5, 3, 2000)
month, day, year = birthday
print("Birthday tuple:", birthday)
print("Month:", month, "Day:", day, "Year:", year)
# Out:
# Birthday tuple: (5, 3, 2000)
# Month: 5 Day: 3 Year: 2000
