# %%
import sys
print("Python executable:\n", sys.executable)

assert ".venv" in sys.executable, """
WRONG KERNEL.
Pick the kernel that ends with '(.venv)' (e.g., 4543 02 Missile Geo (.venv)).
"""
print("✅ Using .venv kernel")
# Out:
# Python executable:
#  C:\Users\demii\OneDrive\Desktop\4543-5993-Spatial-Data\.venv\Scripts\python.exe
# ✅ Using .venv kernel

# %%
import folium
import shapefile
import shapely
import geojson
import numpy
import rich

print("✅ Imports OK")
print("pyshp (shapefile) from:", shapefile.__file__)
# Out:
# ✅ Imports OK
# pyshp (shapefile) from: C:\Users\demii\OneDrive\Desktop\4543-5993-Spatial-Data\.venv\Lib\site-packages\shapefile.py

# %%
m = folium.Map(location=[0, 0], zoom_start=2, tiles="OpenStreetMap")
